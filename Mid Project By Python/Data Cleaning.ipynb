# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dt = pd.read_csv('Dataset_midterm_Section(B).csv')
dt
# Out:
#      Gender   age  sibsp  parch     fare embarked   class      who  alone  \
# 0       0.0  24.0      0      0   7.7958        S   Third    mannn   True
# 1       0.0  17.0      0      0   8.6625        S   Third      man   True
# 2       1.0  21.0      0      0   7.7500        Q   Third   womann   True
# 3       1.0   NaN      0      0   7.6292        Q   Third    woman   True
# 4       1.0  37.0      0      0   9.5875        S   Third  womannn   True
# ..      ...   ...    ...    ...      ...      ...     ...      ...    ...
# 296     0.0  39.0      0      0  13.0000        S  Second      man   True
# 297     1.0  49.0      0      0  25.9292        S   First    woman   True
# 298     1.0  31.0      0      0   8.6833        S   Third    woman   True
# 299     0.0  30.0      0      0   7.2292        C   Third      man   True
# 300     1.0  30.0      1      1  24.1500        S   Third    woman  False
#
#      survived
# 0           0
# 1           0
# 2           0
# 3           0
# ...

# %%
dt.head()
# Out:
#    Gender   age  sibsp  parch    fare embarked  class      who  alone  \
# 0     0.0  24.0      0      0  7.7958        S  Third    mannn   True
# 1     0.0  17.0      0      0  8.6625        S  Third      man   True
# 2     1.0  21.0      0      0  7.7500        Q  Third   womann   True
# 3     1.0   NaN      0      0  7.6292        Q  Third    woman   True
# 4     1.0  37.0      0      0  9.5875        S  Third  womannn   True
#
#    survived
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Gender    297 non-null    float64
#  1   age       240 non-null    float64
#  2   sibsp     301 non-null    int64
#  3   parch     301 non-null    int64
#  4   fare      301 non-null    float64
#  5   embarked  301 non-null    object
#  6   class     297 non-null    object
#  7   who       301 non-null    object
#  8   alone     301 non-null    bool
#  9   survived  301 non-null    int64
# dtypes: bool(1), float64(3), int64(3), object(3)
# memory usage: 21.6+ KB

# %%
unique_values = dt['who'].unique()
print(unique_values)
# Out:
# ['mannn' 'man' 'womann' 'woman' 'womannn' 'child']

# %%
value_counts = dt['who'].value_counts()
print(value_counts)
# Out:
# man        173
# woman       83
# child       22
# mannn        2
# womannn      1
# Name: who, dtype: int64

# %%
dt['who']=dt['who'].replace({'womannn': 'woman', 'mannn': 'man'})
dt
# Out:
#      Gender   age  sibsp  parch     fare embarked   class    who  alone  \
# 0       0.0  24.0      0      0   7.7958        S   Third    man   True
# 1       0.0  17.0      0      0   8.6625        S   Third    man   True
# 2       1.0  21.0      0      0   7.7500        Q   Third  woman   True
# 3       1.0   NaN      0      0   7.6292        Q   Third  woman   True
# 4       1.0  37.0      0      0   9.5875        S   Third  woman   True
# ..      ...   ...    ...    ...      ...      ...     ...    ...    ...
# 296     0.0  39.0      0      0  13.0000        S  Second    man   True
# 297     1.0  49.0      0      0  25.9292        S   First  woman   True
# 298     1.0  31.0      0      0   8.6833        S   Third  woman   True
# 299     0.0  30.0      0      0   7.2292        C   Third    man   True
# 300     1.0  30.0      1      1  24.1500        S   Third  woman  False
#
#      survived
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...

# %%
dt.shape
# Out:
# (301, 10)

# %%
dt = dt.drop_duplicates()
dt
# Out:
#      Gender   age  sibsp  parch     fare embarked   class    who  alone  \
# 0       0.0  24.0      0      0   7.7958        S   Third    man   True
# 1       0.0  17.0      0      0   8.6625        S   Third    man   True
# 2       1.0  21.0      0      0   7.7500        Q   Third  woman   True
# 3       1.0   NaN      0      0   7.6292        Q   Third  woman   True
# 4       1.0  37.0      0      0   9.5875        S   Third  woman   True
# ..      ...   ...    ...    ...      ...      ...     ...    ...    ...
# 296     0.0  39.0      0      0  13.0000        S  Second    man   True
# 297     1.0  49.0      0      0  25.9292        S   First  woman   True
# 298     1.0  31.0      0      0   8.6833        S   Third  woman   True
# 299     0.0  30.0      0      0   7.2292        C   Third    man   True
# 300     1.0  30.0      1      1  24.1500        S   Third  woman  False
#
#      survived
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...

# %%
dt.shape
# Out:
# (281, 10)

# %%
dt['class']=dt['class'].replace({'First': '1', 'Second': '2', 'Third':'3'})
dt
# Out:
#      Gender        age  sibsp  parch     fare embarked class      who  alone  \
# 0       0.0  24.000000      0      0   7.7958        S     3    mannn   True
# 1       0.0  17.000000      0      0   8.6625        S     3      man   True
# 2       1.0  21.000000      0      0   7.7500        Q     3   womann   True
# 3       1.0  34.035083      0      0   7.6292        Q     3    woman   True
# 4       1.0  37.000000      0      0   9.5875        S     3  womannn   True
# ..      ...        ...    ...    ...      ...      ...   ...      ...    ...
# 296     0.0  39.000000      0      0  13.0000        S     2      man   True
# 297     1.0  49.000000      0      0  25.9292        S     1    woman   True
# 298     1.0  31.000000      0      0   8.6833        S     3    woman   True
# 299     0.0  30.000000      0      0   7.2292        C     3      man   True
# 300     1.0  30.000000      1      1  24.1500        S     3    woman  False
#
#      survived
# 0           0
# ...

# %%
dt1 = dt.drop_duplicates()
dt1
# Out:
#      Gender        age  sibsp  parch     fare embarked class      who  alone  \
# 0       0.0  24.000000      0      0   7.7958        S     3    mannn   True
# 1       0.0  17.000000      0      0   8.6625        S     3      man   True
# 2       1.0  21.000000      0      0   7.7500        Q     3   womann   True
# 3       1.0  34.035083      0      0   7.6292        Q     3    woman   True
# 4       1.0  37.000000      0      0   9.5875        S     3  womannn   True
# ..      ...        ...    ...    ...      ...      ...   ...      ...    ...
# 296     0.0  39.000000      0      0  13.0000        S     2      man   True
# 297     1.0  49.000000      0      0  25.9292        S     1    woman   True
# 298     1.0  31.000000      0      0   8.6833        S     3    woman   True
# 299     0.0  30.000000      0      0   7.2292        C     3      man   True
# 300     1.0  30.000000      1      1  24.1500        S     3    woman  False
#
#      survived
# 0           0
# ...

# %%
dt1['age'].mean()
# Out:
# 34.1316681494662

# %%
dt1['age'] = dt1['age'].fillna(np.mean(dt1['age']))
dt1.isnull().sum()
# Out:
# Gender      4
# age         0
# sibsp       0
# parch       0
# fare        0
# embarked    0
# class       4
# who         0
# alone       0
# survived    0
# dtype: int64

# %%
dt['Gender'].mode()
# Out:
# 0    0.0
# Name: Gender, dtype: float64

# %%
dt['Gender'] = dt['Gender'].fillna(np.mode(dt['Gender']))
dt.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12764\2598915704.py in <module>
# ----> 1 dt['Gender'] = dt['Gender'].fillna(np.mode(dt['Gender']))
#       2 dt.isnull().sum()
#
# ~\AppData\Roaming\Python\Python39\site-packages\numpy\__init__.py in __getattr__(attr)
#     309             return Tester
#     310
# --> 311         raise AttributeError("module {!r} has no attribute "
#     312                              "{!r}".format(__name__, attr))
#     313
#
# AttributeError: module 'numpy' has no attribute 'mode'
